# %%
# basic libraries
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('micro_loan.csv')
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 209588   1089.19   1089.19                1.0                0.0  ...
# 209589   1728.36   1728.36                4.0                0.0  ...
# 209590   5861.83   8893.20                3.0                0.0  ...
# 209591    411.83    984.58                2.0               38.0  ...
# 209592    483.92    631.20               13.0                0.0  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
#dropping unamed column because it has no meaning
df.drop(labels=['Unnamed: 0'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (209593, 36)

# %%
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                2.0                0.0              1539  ...
# 1               20.0                0.0              5787  ...
# 2                3.0                0.0              1539  ...
# 3               41.0                0.0               947  ...
# 4                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %% [markdown]
# variables and its meaning
#
#          1.label Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}.
#
# 2. msisdn   mobile number of user.
# 3. aon  age on cellular network in days
# 4. daily_decr30 Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah).
# 5. daily_decr90 Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah).
# 6. rental30 Average main account balance over last 30 days.
# 7. rental90 Average main account balance over last 90 days.
# 8. last_rech_date_ma    Number of days till last recharge of main account.
# 9. last_rech_date_da    Number of days till last recharge of data account.
# 10. last_rech_amt_ma    Amount of last recharge of main account (in Indonesian Rupiah).
# 11. cnt_ma_rech30   Number of times main account got recharged in last 30 days.
# 12. fr_ma_rech30    Frequency of main account recharged in last 30 days.
# 13. sumamnt_ma_rech30   Total amount of recharge in main account over last 30 days (in Indonesian Rupiah).
# 14. medianamnt_ma_rech30    Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah)
# 15. medianmarechprebal30 Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah)
# 16. cnt_ma_rech90   Number of times main account got recharged in last 90 days
# 17. fr_ma_rech90    Frequency of main account recharged in last 90 days
# 18. sumamnt_ma_rech90   Total amount of recharge in main account over last 90 days (in Indonesian Rupee)
# 19. medianamnt_ma_rech90    Median of amount of recharges done in main account over last 90 days at user level (in Indonesian Rupee)
# 20. medianmarechprebal90    Median of main account balance just before recharge in last 90 days at user level (in Indonesian Rupee)
# 21. cnt_da_rech30   Number of times data account got recharged in last 30 days
# 22. fr_da_rech30    Frequency of data account recharged in last 30 days
# 23. cnt_da_rech90   Number of times data account got recharged in last 90 days
# 24. fr_da_rech90    Frequency of data account recharged in last 90 days
# 25. cnt_loans30 Number of loans taken by user in last 30 days
# 26. amnt_loans30    Total amount of loans taken by user in last 30 days
# 27. maxamnt_loans30 maximum amount of loan taken by the user in last 30 days
# 28. medianamnt_loans30  Median of amounts of loan taken by the user in last 30 days
# 29. cnt_loans90 Number of loans taken by user in last 90 days
# 30. amnt_loans90 Total amount of loans taken by user in last 90 days
# 31. maxamnt_loans90 maximum amount of loan taken by the user in last 90 days
# 32. medianamnt_loans90  Median of amounts of loan taken by the user in last 90 days
# 33. payback30   Average payback time in days over last 30 days
# 34. payback90   Average payback time in days over last 90 days
# 35. pcircle telecom circle
# 36. pdate   date

# %%
#column names 
print(df.columns)
print(len(df.columns))
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')
# 36

# %%
#data types
df.dtypes
# Out:
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# ...

# %%
#information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %% [markdown]
# interpretation
#
#     1)there are 36 variables are present
#     2)in which total 21 float values, 12 integer values, and 3 objective
#     3)no null value present in the dataset

# %%
# to checking null values
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull())

# %%
df.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# ...

# %% [markdown]
# interpretation
#
#       1)there is no null values are present in the dataset

# %%
#data cleaning
#Dropping the pdate columns because pdate not affect the target / leabel.
df.drop(columns=['pdate'],axis=1, inplace = True)

# %%
df.shape
# Out:
# (209593, 35)

# %%
#summary statistics.
df.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %% [markdown]
# interpretation:
#
#     1)lots of differences in mean values of all variables
#     2)standard deviation is huge in some of the variables
#     3)mean is greater than median in all the variables
#     4)the difference between third quartile and max values is high in most of the variable so outliers are present.

# %%
#correlation table
dfcorr=df.corr()
dfcorr
# Out:
#                          label       aon  daily_decr30  daily_decr90  \
# label                 1.000000 -0.003785      0.168298      0.166150
# aon                  -0.003785  1.000000      0.001104      0.000374
# daily_decr30          0.168298  0.001104      1.000000      0.977704
# daily_decr90          0.166150  0.000374      0.977704      1.000000
# rental30              0.058085 -0.000960      0.442066      0.434685
# rental90              0.075521 -0.000790      0.458977      0.471730
# last_rech_date_ma     0.003728  0.001692      0.000487      0.000908
# last_rech_date_da     0.001711 -0.001693     -0.001636     -0.001886
# last_rech_amt_ma      0.131804  0.004256      0.275837      0.264131
# cnt_ma_rech30         0.237331 -0.003148      0.451385      0.426707
# fr_ma_rech30          0.001330 -0.001163     -0.000577     -0.000343
# sumamnt_ma_rech30     0.202828  0.000707      0.636536      0.603886
# medianamnt_ma_rech30  0.141490  0.004306      0.295356      0.282960
# ...

# %%
#correlation with heatmap
plt.figure(figsize=(26,14))
sns.heatmap(dfcorr,annot=True)

# %% [markdown]
# interpretation:
#
#     1)most of the correlation is near to zero.
#     2)daily_decr30 and daily_decr90 features are highly correlated with each other.
#     3)rental30 and rental90 features are highly correlated with each other.
#     4)cnt_loans30 and amount_loans30 columns are highly correlated with each other.
#     5)amount_loans30 is also highly correlated with amount_loans90 column.
#     6)medianamnt_loans30 and medianamnt_loans90 is highly correlated with each other.

# %%
#dropping pcircle because it has only one object and it wont impact the baled
df.drop(columns=['pcircle'],axis=1, inplace = True)

# %%
df.shape
# Out:
# (209593, 34)

# %%
#univariate data analysis
numeric_data = df._get_numeric_data()
for i in numeric_data.columns:
    f=plt.figure(figsize=(14,3))
    f.add_subplot(1,2,1)
    sns.distplot(numeric_data[i].describe())
    f.add_subplot(1,2,2)
    sns.boxplot(numeric_data[i])

# %% [markdown]
# interpretation:
#
#     1)from distribution plot we see that maximum variables are highly skewed
#     2)from box plot we see that lots of variables have a outliers

# %%
#bivariate data analysis
#scatter plot of that variables having high correlation

# %%
plt.scatter(df['daily_decr30'],df['daily_decr90'])
plt.show()
plt.scatter(df['rental30'],df['rental90'])
plt.show()
plt.scatter(df['amnt_loans30'],df['cnt_loans30'])
plt.show()
plt.scatter(df['medianamnt_loans30'],df['medianamnt_loans30'])
plt.show()

# %% [markdown]
# interpretation:
#
#     1)all this variables are highly correlated and they almost have similar data by seeing scatterplot

# %%
#dropping this variable to avoid overfitting
df.drop(columns=['daily_decr90','rental90','amnt_loans90','medianamnt_loans90'],axis=1, inplace = True)

# %%
df.shape
# Out:
# (209593, 30)

# %%
#checking unique values
print('unique values in dataset')
for i in df:
    print(i,'-',df[i].nunique())
# Out:
# unique values in dataset
# label - 2
# msisdn - 186243
# aon - 4507
# daily_decr30 - 147026
# rental30 - 132148
# last_rech_date_ma - 1186
# last_rech_date_da - 1174
# last_rech_amt_ma - 70
# cnt_ma_rech30 - 71
# fr_ma_rech30 - 1083
# sumamnt_ma_rech30 - 15141
# medianamnt_ma_rech30 - 510
# medianmarechprebal30 - 30428
# cnt_ma_rech90 - 110
# fr_ma_rech90 - 89
# sumamnt_ma_rech90 - 31771
# medianamnt_ma_rech90 - 608
# medianmarechprebal90 - 29785
# cnt_da_rech30 - 1066
# fr_da_rech30 - 1072
# cnt_da_rech90 - 27
# fr_da_rech90 - 46
# cnt_loans30 - 40
# amnt_loans30 - 48
# maxamnt_loans30 - 1050
# medianamnt_loans30 - 6
# cnt_loans90 - 1110
# maxamnt_loans90 - 3
# payback30 - 1363
# payback90 - 2381

# %% [markdown]
# interpretation:
#
#     1)lots of unique values are present in all variables

# %%
#Data cleaning variable-label
print('unique values:',df['label'].unique())
print(df['label'].value_counts())
# Out:
# unique values: [0 1]
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %%
#countplot of label
sns.countplot(x='label',data=df)

# %% [markdown]
# interpretation :
#
#     1)as we can see that the user paid back the credit amount within 5 days of issuing the loan is more that that not paid.
#     2)it has inbalance dataset

# %%
#data cleaning-msisdn
#msisdn has a mobile number of customer 

df['msisdn'].value_counts()
# Out:
# 04581I85330    7
# 47819I90840    7
# 71742I90843    6
# 43096I88688    6
# 67324I84453    6
#               ..
# 02680I90845    1
# 33619I90845    1
# 35883I70780    1
# 50342I70787    1
# 89219I85348    1
# Name: msisdn, Length: 186243, dtype: int64

# %% [markdown]
# interpretation:
#
#     1)as we can see mobile number is unique identity but it has registered more than one times

# %%
#we remove duplicate mobile numbers
df.drop_duplicates(subset='msisdn', keep="first",inplace=True)

# %%
df.shape
# Out:
# (186243, 30)

# %%
#Dropping the msisdn columns beause it's unique identity(mobile number) of each customer 
df.drop(columns=['msisdn'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (186243, 29)

# %%
#data cleaning-maxamnt_loans90
df['maxamnt_loans90'].unique()
# Out:
# array([ 6, 12,  0], dtype=int64)

# %%
#drop those rows which maxamnt_loans90 is 0 Because 0 loan amount represent no loan history.
df.drop(axis=0, index=df[df['maxamnt_loans90']== 0].index, inplace=True)

# %%
df.shape
# Out:
# (184216, 29)

# %%
#multivariate analysis
df.hist(figsize=(20,20))
plt.show()

# %%
#lets chcek the skewness in the dataset
df.skew()
# Out:
# label                   -2.070498
# aon                     10.379090
# daily_decr30             4.020837
# rental30                 4.592779
# last_rech_date_ma       14.876675
# last_rech_date_da       14.766298
# last_rech_amt_ma         3.869835
# cnt_ma_rech30            3.470245
# fr_ma_rech30            14.848789
# sumamnt_ma_rech30        7.157453
# medianamnt_ma_rech30     3.545551
# medianmarechprebal30    14.667285
# cnt_ma_rech90            3.564452
# fr_ma_rech90             2.251964
# sumamnt_ma_rech90        5.255143
# medianamnt_ma_rech90     3.783303
# medianmarechprebal90    44.236177
# cnt_da_rech30           17.739564
# fr_da_rech30            14.755584
# cnt_da_rech90           28.288425
# fr_da_rech90            28.801346
# cnt_loans30              2.757317
# amnt_loans30             3.024594
# maxamnt_loans30         17.730979
# medianamnt_loans30       4.442298
# cnt_loans90             16.686202
# maxamnt_loans90          2.269307
# ...

# %% [markdown]
# interpretation:
#
#     1)all variables are skewed to right or left
#     2)most of the variables are highly skewed

# %%
#cheking for outliers
df1=df.copy()
df1.shape
# Out:
# (184216, 29)

# %%
from scipy.stats import zscore
z=np.abs(zscore(df1))
threshold=3
np.where(z>3)
df1_new=df1[(z<3).all(axis=1)]
df1_new.shape
# Out:
# (144678, 29)

# %%
#after removing outliers we lost near about 22% of data so cant take that much loss of data so we keep the outliers

# %%
#conclusion of EDA

# %% [markdown]
# interpretation:
#
#     1.There are no null values in the dataset.
#     2.The dataset is imbalanced. Label ‘1’ has approximately 87% records, while, label ‘0’ has approximately 13% records.
#     3.maxamnt_loans90 columns gives information about customers with no loan history.
#     4.msisdn feature shows some values which might not be realistic. So drop the row which contain not realistic value.
#     5.There are some rows which is repeated means duplicate entries are present in our dataset.
#     6.The collected data is only for one Telecom circle area.
#     7.lots of variation present in the dataset(i.e. dataset contain 4 digit number and 1 digit number)
#     8.most of the variable are not correlated to each other

# %%
#model training

# %%
df.head(1)
# Out:
#    label    aon  daily_decr30  rental30  last_rech_date_ma  last_rech_date_da  \
# 0      0  272.0       3055.05    220.13                2.0                0.0
#
#    last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  ...  \
# 0              1539              2          21.0             3078.0  ...
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
#
#    medianamnt_loans30  cnt_loans90  maxamnt_loans90  payback30  payback90
# 0                 0.0          2.0                6       29.0       29.0
#
# [1 rows x 29 columns]

# %%
y=df.iloc[:,0:1]
y.head()
# Out:
#    label
# 0      0
# 1      1
# 2      1
# 3      1
# 4      1

# %%
y.shape
# Out:
# (184216, 1)

# %%
x=df.iloc[:,1:]
x.head()
# Out:
#      aon  daily_decr30  rental30  last_rech_date_ma  last_rech_date_da  \
# 0  272.0   3055.050000    220.13                2.0                0.0
# 1  712.0  12122.000000   3691.26               20.0                0.0
# 2  535.0   1398.000000    900.13                3.0                0.0
# 3  241.0     21.228000    159.42               41.0                0.0
# 4  947.0    150.619333   1098.90                4.0                0.0
#
#    last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  \
# 0              1539              2          21.0             3078.0
# 1              5787              1           0.0             5787.0
# 2              1539              1           0.0             1539.0
# 3               947              0           0.0                0.0
# 4              2309              7           2.0            20029.0
#
#    medianamnt_ma_rech30  ...  cnt_da_rech90  fr_da_rech90  cnt_loans30  \
# ...

# %%
x.shape
# Out:
# (184216, 28)

# %%
#Scaling in input variables
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
#Splitting the data into training and testing data

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=42,stratify=y)

# %%
print('shape of x_train----',x_train.shape)
print('shape of x_test----',x_test.shape)
print('shape of y_train----',y_train.shape)
print('shape of y_test----',y_test.shape)
# Out:
# shape of x_train---- (138162, 28)
# shape of x_test---- (46054, 28)
# shape of y_train---- (138162, 1)
# shape of y_test---- (46054, 1)

# %%
#Lets chcek logistic regression
from sklearn.linear_model import LogisticRegression
#Importing error metrics
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import GridSearchCV, KFold

# %%
log_class=LogisticRegression()
grid={'C':10.0**np.arange(-2,3),'penalty':['l1','l2']}
cv=KFold(n_splits=15,random_state=None,shuffle=False)

# %%
clf=GridSearchCV(log_class,grid,cv=cv,n_jobs=-1,scoring='f1_macro')
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('score',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[  177  6288]
#  [  128 39461]]
# score 0.860685282494463
#               precision    recall  f1-score   support
#
#            0       0.58      0.03      0.05      6465
#            1       0.86      1.00      0.92     39589
#
#     accuracy                           0.86     46054
#    macro avg       0.72      0.51      0.49     46054
# weighted avg       0.82      0.86      0.80     46054

# %%
#Lets chcek random forest
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('score',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 2827  3638]
#  [  966 38623]]
# score 0.9000303990967126
#               precision    recall  f1-score   support
#
#            0       0.75      0.44      0.55      6465
#            1       0.91      0.98      0.94     39589
#
#     accuracy                           0.90     46054
#    macro avg       0.83      0.71      0.75     46054
# weighted avg       0.89      0.90      0.89     46054

# %%
#random forest is giving max score so we use random forest classifier for under,over and smote sampling

# %%
#since it is imbalanced dataset so we will focus on auc-roc scor

from collections import Counter
Counter(y_train['label'])
# Out:
# Counter({1: 118767, 0: 19395})

# %%
#we know that oue target variable is imbalance so we use resampling method to balance it

# %% [markdown]
# # under sampling

# %%
from imblearn.under_sampling import NearMiss

# %%
ns = NearMiss(.8)
x_train_ns,y_train_ns = ns.fit_resample(x_train,y_train)
print("The number of classes before fit {}".format(Counter(y_train['label'])))
print("The number of classes after fit {}".format(Counter(y_train_ns['label'])))
# Out:
# The number of classes before fit Counter({1: 118767, 0: 19395})
# The number of classes after fit Counter({1: 24243, 0: 19395})

# %%
#random forest for under sampling
from sklearn.ensemble import RandomForestClassifier
classifier_us = RandomForestClassifier()
classifier_us.fit(x_train_ns,y_train_ns)
y_pred=classifier_us.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('score',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 4791  1674]
#  [29297 10292]]
# score 0.3275068397967603
#               precision    recall  f1-score   support
#
#            0       0.14      0.74      0.24      6465
#            1       0.86      0.26      0.40     39589
#
#     accuracy                           0.33     46054
#    macro avg       0.50      0.50      0.32     46054
# weighted avg       0.76      0.33      0.38     46054

# %% [markdown]
# # smote

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()

# %%
x_train_st,y_train_st=sm.fit_resample(x_train,y_train)

# %%
print("The number of classes before fit ",(Counter(y_train['label'])))
print("The number of classes after fit ",(Counter(y_train_st['label'])))
# Out:
# The number of classes before fit  Counter({1: 118767, 0: 19395})
# The number of classes after fit  Counter({1: 118767, 0: 118767})

# %%
#random forest for smote
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(x_train_st,y_train_st)
y_pred=classifier.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('score',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 3763  2702]
#  [ 2556 37033]]
# score 0.8858296782038476
#               precision    recall  f1-score   support
#
#            0       0.60      0.58      0.59      6465
#            1       0.93      0.94      0.93     39589
#
#     accuracy                           0.89     46054
#    macro avg       0.76      0.76      0.76     46054
# weighted avg       0.88      0.89      0.89     46054

# %% [markdown]
# # over sampling

# %%
from imblearn.over_sampling import RandomOverSampler
os = RandomOverSampler(0.75)
x_train_os,y_train_os = os.fit_resample(x_train,y_train)
print("The number of classes before fit ",(Counter(y_train['label'])))
print("The number of classes after fit ",(Counter(y_train_os['label'])))
# Out:
# The number of classes before fit  Counter({1: 118767, 0: 19395})
# The number of classes after fit  Counter({1: 118767, 0: 89075})

# %%
#lets check gaussain nb
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train_os,y_train_os)
y_pred=gnb.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('score',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 5601   864]
#  [18793 20796]]
# score 0.5731749685152213
#               precision    recall  f1-score   support
#
#            0       0.23      0.87      0.36      6465
#            1       0.96      0.53      0.68     39589
#
#     accuracy                           0.57     46054
#    macro avg       0.59      0.70      0.52     46054
# weighted avg       0.86      0.57      0.63     46054

# %%
#decision tree for over sample
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train_os,y_train_os)
y_pred_dt=dtc.predict(x_test)
print(confusion_matrix(y_test,y_pred_dt))
print('score',accuracy_score(y_test,y_pred_dt))
print(classification_report(y_test,y_pred_dt))
# Out:
# [[ 3127  3338]
#  [ 3509 36080]]
# score 0.851326703435098
#               precision    recall  f1-score   support
#
#            0       0.47      0.48      0.48      6465
#            1       0.92      0.91      0.91     39589
#
#     accuracy                           0.85     46054
#    macro avg       0.69      0.70      0.70     46054
# weighted avg       0.85      0.85      0.85     46054

# %%
#extra tree for over sampling
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier()
etc.fit(x_train_os,y_train_os)
y_pred_et=etc.predict(x_test)
print(confusion_matrix(y_test,y_pred_et))
print('score',accuracy_score(y_test,y_pred_et))
print(classification_report(y_test,y_pred_et))
# Out:
# [[ 2645  3820]
#  [ 1081 38508]]
# score 0.8935814478655492
#               precision    recall  f1-score   support
#
#            0       0.71      0.41      0.52      6465
#            1       0.91      0.97      0.94     39589
#
#     accuracy                           0.89     46054
#    macro avg       0.81      0.69      0.73     46054
# weighted avg       0.88      0.89      0.88     46054

# %%
#bagging classifier for over sample 
from sklearn.ensemble import BaggingClassifier
bc = BaggingClassifier()
bc.fit(x_train_os,y_train_os)
y_pred_bc=bc.predict(x_test)
print(confusion_matrix(y_test,y_pred_bc))
print('score',accuracy_score(y_test,y_pred_bc))
print(classification_report(y_test,y_pred_bc))
# Out:
# [[ 3624  2841]
#  [ 2677 36912]]
# score 0.8801841316715161
#               precision    recall  f1-score   support
#
#            0       0.58      0.56      0.57      6465
#            1       0.93      0.93      0.93     39589
#
#     accuracy                           0.88     46054
#    macro avg       0.75      0.75      0.75     46054
# weighted avg       0.88      0.88      0.88     46054

# %%
#random forest classifier for over sample
from sklearn.ensemble import RandomForestClassifier
RFclassifier = RandomForestClassifier()
RFclassifier.fit(x_train_os,y_train_os)
y_pred=RFclassifier.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('score',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 3281  3184]
#  [ 1498 38091]]
# score 0.8983367351370131
#               precision    recall  f1-score   support
#
#            0       0.69      0.51      0.58      6465
#            1       0.92      0.96      0.94     39589
#
#     accuracy                           0.90     46054
#    macro avg       0.80      0.73      0.76     46054
# weighted avg       0.89      0.90      0.89     46054

# %%
#AUC_Score for random forest classifier for over sample
from sklearn.metrics import roc_auc_score
auc_score=roc_auc_score(y_test,RFclassifier.predict(x_test))
print("AUC_Score:",auc_score)
# Out:
# AUC_Score: 0.7348315699418643

# %%
#AUC_ROC Curve of random forest classifier for over sample
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
y_pred_prob=RFclassifier.predict_proba(x_test)[:,0]
fpr,tpr,thredholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='RFC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Random Forest Classifier(over sample)')
plt.show()
auc_score=roc_auc_score(y_test,RFclassifier.predict(x_test))
print(auc_score)
# Out:
# 0.7348315699418643

# %%
#Saving the model
import joblib

#Save the model as a pickle in a file
joblib.dump(RFclassifier,'Micro_credit_loan.pkl')
# Out:
# ['Micro_credit_loan.pkl']
